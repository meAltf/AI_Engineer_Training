# %%
x = 5+11

# %%
print(x)
# Out:
# 16

# %%
16/3
# Out:
# 5.333333333333333

# %%
float(16)/3
# Out:
# 5.333333333333333

# %%
16 % 3
# Out:
# 1

# %%
15 % 5
# Out:
# 0

# %%
5*3
# Out:
# 15

# %%
5**3
# Out:
# 125

# %%
y = 5**5

# %%
y
# Out:
# 3125

# %%
y == 3125
# Out:
# True

# %%
y == 3126
# Out:
# False

# %%
# It's a comment not code
# It's also a comment
print(9, 100)
# Out:
# 9 100

# %%
# if want to continue in next line, needs to use \ to follow the file
2.5 * 8 + \
10
# Out:
# 30.0
