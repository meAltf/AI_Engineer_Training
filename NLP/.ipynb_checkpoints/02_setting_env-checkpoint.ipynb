# %%
# conda: an environment & package manager
# pip: python's built-in package installer
# pypi: the official python package index

# %%
# command to run in terminal: conda create --name nlp_learning_env python=3.11
# After running this, activatet the env: conda activate nlp_learning_env

# %%
# to install all the required packages:
pip install "numpy<2.0" nltk==3.9.1 pandas==2.2.3 matplotlib==3.10.0 spacy==3.8.3 textblob==0.18.0.post0 vaderSentiment==3.3.2 transformers==4.47.1 scikit-learn==1.6.0 gensim==4.3.3 seaborn==0.13.2 torch==2.5.1 ipywidgets==8.1.5 chardet ipykernel jupyterlab notebook

# %%
# next, download spaCy language model: an opnesource model for NLP usesases
python -m spacy download en_core_web_sm

# %%
# register new environment as Jupyter kernel
python -m ipykernel install --user --name=nlp_course_env
