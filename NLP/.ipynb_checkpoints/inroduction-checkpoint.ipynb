# %%
# NLP: Natural Language Processing
# A Field of AI that allows computers to understand, interpret and generate human language data
# key characteristic of supervised NLP: It relies on labeled data to train models

# %%
# Supervised Learning:
# Training an algorithm to learn the relationship between input and output data (both provided)
# labeled data

# %%
# Un-supervised Learning:
# Unlabelled data
# Wo don't need to provide output data, based on input data provided , that algorithm itself find the pattern and propsed output.
