# %%
# Text tagging:

# %%
# POS : parts of speech tagging
#   Tagging based on parts of speech, noun, verb, adj etc.


# NER : Named entity recognition
#   Tagging based on person, location, ordinal, geo-political entity
