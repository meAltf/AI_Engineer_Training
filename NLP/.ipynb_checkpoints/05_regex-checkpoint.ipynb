# %%
# regex: regular expression
# A special way of writing patterns to search through text

# %%
# re : Python's built in library for workign with regex

# %%
# raw string
# "/n" default: new line but to use it as a raw string neeeds to put: [  r"/n" means "/n" raw string ]

# %%
import re

# %%
my_folder = "C:\desktop\notes"
print(my_folder)
# Out:
# C:\desktop
# otes

# %%
# with r, raw string
my_folder = r"C:\desktop\notes"
print(my_folder)
# Out:
# C:\desktop\notes

# %%
# search("pattern", "input value") | It will search the pattern value in input value | required 2 arguments
result_search = re.search("pattern1", r"string to contain the pattern1 neeeds to search")
print(result_search)
# Out:
# <re.Match object; span=(22, 30), match='pattern1'>

# %%
result_search_2 = re.search("abcd", r"string to contain the pattern neeeds to search not in the string")
print(result_search_2)
# Out:
# None

# %%
# re.sub() : searches for a specific text within a string and replaces it with new content | required 3 arguments
# re.sub("old text", "new text", "the string u want to replace")

# %%
string = r"sara was able to help me find the items i needed quickly"

# %%
new_string = re.sub("sara","sarah",string)
print(new_string)
# Out:
# sarah was able to help me find the items i needed quickly

# %%
# complex regex

# %%
customer_reviews = ['sam was a great help to me in the store', 
                    'the cashier was very rude to me, I think her name was eleanor', 
                    'amazing work from sadeen!', 
                    'sarah was able to help me find the items i needed quickly', 
                    'lucy is such a great addition to the team', 
                    'great service from sara she found me what i wanted'
                   ]

# %%
# Find only sarah's reviews but account for the spelling of sara
# the ? after r means it is an optional character to match, so our search will look for sarah and sara

# %%
sarah_reviews = []
pattern_to_find = r"sarah?"

for string in customer_reviews:
    if(re.search(pattern_to_find, string)):
        sarah_reviews.append(string)
print(sarah_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']

# %%
# Find reviews that start with the letter a
# # the ^ operator to indicates the start of a string

# %%
a_review = []
pattern_to_find = r"^a"

for string in customer_reviews:
    if(re.search(pattern_to_find, string)):
        a_review.append(string)

print(a_review)
# Out:
# ['amazing work from sadeen!']

# %%
# Find reviews that end with the letter y
# the $ operator to indicate the end of a string

# %%
y_review = []
pattern_to_find = r"y$"

for string in customer_reviews:
    if(re.search(pattern_to_find, string)):
        y_review.append(string)

print(y_review)
# Out:
# ['sarah was able to help me find the items i needed quickly']

# %%
# Find reviews that contain the words needed or wanted
# the pipe operator | can be used to mean OR

# %%
needwant_review = []
pattern_to_find = r"(need|want)ed"

for string in customer_reviews:
    if(re.search(pattern_to_find, string)):
        needwant_review.append(string)

print(needwant_review)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']

# %%
# Remove anything from the review that isn't a word or a space (i.e. remove punctuation)
# [^ ] means "not", \w means word and \s means whitespace: so find anything that is not a word or a space
# \w : word characters means letter, numbers, underscore, symbol

# %%
no_punct_reviews = []
pattern_to_find = r"[^\w\s]"

for string in customer_reviews:
    no_punch_string = re.sub(pattern_to_find, "", string)
    no_punct_reviews.append(no_punch_string)

print(no_punct_reviews)
# Out:
# ['sam was a great help to me in the store', 'the cashier was very rude to me I think her name was eleanor', 'amazing work from sadeen', 'sarah was able to help me find the items i needed quickly', 'lucy is such a great addition to the team', 'great service from sara she found me what i wanted']
