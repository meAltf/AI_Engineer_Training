# %%
# pandas:
# It helps you store, clean, explore, and analyze data quickly and efficiently in python
# uses: Load data from files like CSV, Excel, or SQL databases | Filter rows and select specific columns | Perform calculations or summaries (like averages or totals)
# Pandas makes data manipulation easy and efficient.

# %%
# pd.Series & pd.DataFrame 
# A Series is a one-dimensional labeled array — like a single column in a spreadsheet.
# A DataFrame is a two-dimensional table — like a full spreadsheet with rows and columns.

# %%
# pd.Series(input)
# pd.DataFrame(input)

# %%
import pandas as pd
numbers = pd.Series([10, 20, 30, 40])
print(numbers)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["London", "Paris", "Berlin"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age    City
# 0    Alice   25  London
# 1      Bob   30   Paris
# 2  Charlie   35  Berlin
