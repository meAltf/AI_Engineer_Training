# %%
# Text tagging:

# %%
# POS : parts of speech tagging
#   labelling each word in a sentence with its grammatical role [  based on parts of speech, noun, verb, adj etc. ]


# NER : Named entity recognition
#   Tagging based on person, location, ordinal, geo-political entity

# %%
# spaCy:
# An NLP library that comes with pretrained models capable of recognizing parts of speech, named entities, and other linguistic features.

# %%
# spacy document:
# An object that stores the text along with all the linguistic information spacy generates

# %%
import spacy
import pandas as pd
# Out:
# /opt/anaconda3/envs/nlp_learning_env/lib/python3.11/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(

# %%
nlp = spacy.load('en_core_web_sm')
