# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
False or True
# Out:
# True

# %%
# order of the logical operators | Not-And-Or
True and not True
# Out:
# False

# %%
False or not True and True
# Out:
# False

# %%
True and not True or True
# Out:
# True

# %%
# Identity operators | is and not is
5 == 6
# Out:
# False

# %%
5 != 6
# Out:
# True

# %%
5 == 6
# Out:
# False
