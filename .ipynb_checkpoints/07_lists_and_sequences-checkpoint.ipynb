# %%
# list in python
Numbers = [10, 25, 40, 50]
print(Numbers[2])
print(Numbers[-3]) # 25
Numbers[0] = 15
del(Numbers[1])
print(Numbers)
# Out:
# 40
# 25
# [15, 40, 50]

# %%
# sequences
# append | method.append 
# extend | method.extend
participants = ["robert", "wyatt", "Richard", "Isabelle"]
participants.append("Hugo")
print(participants)
participants.extend(["Aymen","sercan"])
print(participants)
del(participants[5])
print(participants)
len(participants)
print(len("sercan"))
# Out:
# ['robert', 'wyatt', 'Richard', 'Isabelle', 'Hugo']
# ['robert', 'wyatt', 'Richard', 'Isabelle', 'Hugo', 'Aymen', 'sercan']
# ['robert', 'wyatt', 'Richard', 'Isabelle', 'Hugo', 'sercan']
# 6
