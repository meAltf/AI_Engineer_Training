# %%
x = [1,3,5,7,9]
x
# Out:
# [1, 3, 5, 7, 9]

# %%
x = 5

# %%
x
# Out:
# 5

# %%
y = 99

# %%
print(y+x)
# Out:
# 104

# %%
x,y = (1,4)
x
y
# Out:
# 4

# %%
print('Click "Ok"')
# Out:
# Click "Ok"

# %%
1 + 2
# Out:
# 3

# %%
"car + bike"
# Out:
# 'car + bike'

# %%
'car+bike'
# Out:
# 'car+bike'

# %%
'car' + 'bike'
# Out:
# 'carbike'

# %%
'car' + 'bike'
# Out:
# 'carbike'

# %%
print("I'm good")
# Out:
# I'm good

# %%
'I\'m good'
# Out:
# "I'm good"

# %%
'car ' + 'bike'
# Out:
# 'car bike'

# %%
'Done with Integer, boolean, float, string'
# Out:
# 'Done with Integer, boolean, float, string'

# %%
1,2,5,8.99,'car'
# Out:
# (1, 2, 5, 8.99, 'car')

# %%
x = 100
print(str(x),'days')
# Out:
# 100 days
