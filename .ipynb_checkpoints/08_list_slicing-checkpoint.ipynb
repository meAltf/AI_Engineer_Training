# %%
# list slicing | 
participants = ["robert", "wyatt", "Richard", "Isabelle", "sercan"]
participants
# Out:
# ['robert', 'wyatt', 'Richard', 'Isabelle', 'sercan']

# %%
# result: 1- including, 3- excluding | 0-based indexing
participants[1:3]
# Out:
# ['wyatt', 'Richard']

# %%
# end - excluding
participants[:2]
# Out:
# ['robert', 'wyatt']

# %%
participants[3:]
# Out:
# ['Isabelle', 'sercan']

# %%
participants[-2:]
# Out:
# ['Isabelle', 'sercan']

# %%
# index: to find the index of the element
participants.index("Isabelle")
# Out:
# 3

# %%
newComers = ["Alataf", "Nadir"]
newComers
# Out:
# ['Alataf', 'Nadir']

# %%
Bigger_List = [ participants, newComers]
Bigger_List
# Out:
# [['robert', 'wyatt', 'Richard', 'Isabelle', 'sercan'], ['Alataf', 'Nadir']]

# %%
participants.sort()
participants
# Out:
# ['Isabelle', 'Richard', 'robert', 'sercan', 'wyatt']

# %%
participants.sort(reverse=True)
participants
# Out:
# ['wyatt', 'sercan', 'robert', 'Richard', 'Isabelle']

# %%
Numbers = [1,2,3,4,5]
Numbers.sort()
print(Numbers)
Numbers.sort(reverse=True)
print(Numbers)
# Out:
# [1, 2, 3, 4, 5]
# [5, 4, 3, 2, 1]
