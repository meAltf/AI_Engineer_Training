# %%
x = [1,3,5,7,9]
x
# Out:
# [1, 3, 5, 7, 9]

# %%
x = 5

# %%
x
# Out:
# 5

# %%
y = 99

# %%
print(y+x)
# Out:
# 104

# %%
x,y = (1,4)
x
y
# Out:
# 4

# %%
print('Click "Ok"')
# Out:
# Click "Ok"
