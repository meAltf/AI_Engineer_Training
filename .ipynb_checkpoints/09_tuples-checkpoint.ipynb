# %%
# Tuples: type of data sequences | It's Immutable
# Tuple's elements are places within parenthesis (), not in brackets []
# btw tuple are by default data sequence in python

# %%
x = (10,20,30)
x
# Out:
# (10, 20, 30)

# %%
# btw tuple are by default data sequence in python
y = 2,6,8
y
# Out:
# (2, 6, 8)

# %%
x[0]
# Out:
# 10

# %%
List_1 = [x,y]
List_1
# Out:
# [(10, 20, 30), (2, 6, 8)]

# %%
# split : allow you to extract the provided name and age separately. 
(age, year_of_school) = "30,15".split(',')
print(age)
print(year_of_school)
# Out:
# 30
# 15

# %%
# Functions can provide tuples as return values
def square_info(x):
    A = x *x;
    P = 4*x;
    print("Area and perimeter:")
    return A,P
square_info(5)
# Out:
# Area and perimeter:
# (25, 20)
